# %%
import os
import pandas as pd
import numpy as np
from os.path import isdir
from flask import Flask, render_template, request
from werkzeug.wrappers import Request, Response

# %%
app = Flask(__name__)

PATH = os.getcwd()+'\\class_photo\\'
if (not os.path.isdir(PATH)):
    os.mkdir(PATH)

@app.route('/')
def main():
    return render_template('capture_attendance.html')


@app.route('/submit', methods=['POST'])
def check_att():
    
    ##-----saves_images----------##
    temp = request.files['image']
    temp1 = PATH + temp.filename
    temp.save(temp1)
    
    ##-------Runs_driver2_code-----------##
    import ipynb.fs.full.driver_code2 as fd
    
    ##-----Attendace_list-------##
    arr  = np.array(fd.df)
    return render_template('capture_attendance.html', data=arr, temp=1)

@app.route('/trained')
def train():
    
    ##-------Runs_driver2_code-----------##
    import ipynb.fs.full.driver_code1 as dc
    return render_template('capture_attendance.html')

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 3000, app)
# Out:
#  * Running on http://localhost:3000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/May/2021 23:42:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2021 23:42:17] "GET /favicon.ico HTTP/1.1" 404 -
# Using TensorFlow backend.
# Filename :  Capture.jpg
# Checking extension...
# Path:  C:\Users\samkit\Tensorflow_Testing\IBM_Project\class_photo\Capture.jpg
# Loading and Displaying image...
# Creating MTCNN object for detection...
# Number of faces detected:  5
# C:\Users\samkit\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ['Aditya_Shankar_B247', 'Aryan_Verma_B255', 'Samkit_Saraf_B241', 'Shashwat_Tare_B252', 'Varun_Kumar_B245', 'Varun_Vasani_B250']
# 127.0.0.1 - - [27/May/2021 23:43:09] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2021 23:44:54] "GET /input_videos/Varun.mp4 HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2021 23:46:52] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2021 23:46:54] "GET /input_videos/Varun.mp4 HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2021 23:51:03] "GET / HTTP/1.1" 200 -
# dta imported!
# em imported!
# >loaded 14 examples for class: Aditya_Shankar_B247
# >loaded 20 examples for class: Aryan_Verma_B255
# >loaded 20 examples for class: Samkit_Saraf_B241
# >loaded 20 examples for class: Shashwat_Tare_B252
# >loaded 20 examples for class: Varun_Kumar_B245
# >loaded 20 examples for class: Varun_Vasani_B250
# (114, 160, 160, 3) (114,)
# >loaded 4 examples for class: Aditya_Shankar_B247
# >loaded 5 examples for class: Aryan_Verma_B255
# >loaded 5 examples for class: Samkit_Saraf_B241
# >loaded 5 examples for class: Shashwat_Tare_B252
# >loaded 5 examples for class: Varun_Kumar_B245
# >loaded 5 examples for class: Varun_Vasani_B250
# Loaded:  (114, 160, 160, 3) (114,) (29, 160, 160, 3) (29,)
# C:\Users\samkit\Anaconda3\envs\tensorflow\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Loaded Model
# 127.0.0.1 - - [27/May/2021 23:51:37] "GET /trained HTTP/1.1" 200 -
# Dataset: train=114, test=29
# Accuracy: train=100.000, test=100.000
# 127.0.0.1 - - [27/May/2021 23:53:06] "GET /trained HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2021 23:53:08] "GET /trained HTTP/1.1" 200 -
